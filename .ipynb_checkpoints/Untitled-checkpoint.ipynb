# %%
from ResamplingMSA import reorder_afa_file, msa_fasta_to_a3m, unblock_a3m, unblock_efa
from msa_utils import *
import subprocess
HHREFROMAT = "/home/adaddi/data/hh-suite/scripts/reformat.pl"

# %%
in_file = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env.abc.1.afa"
re_file = f'{in_file.split(".")[0]}_re.fasta'
out_file = f'{in_file.split(".")[0]}.a3m'
reorder_afa_file(in_file, re_file)
msa_fasta_to_a3m(re_file, out_file, HHREFROMAT)
unblock_a3m(out_file)
# Out:
# REORDER QUERY ON TOP
# Has Querysequence
# MSA FASTA TO A3M
# Reformatted /home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env_re.fasta with 871 sequences from fas to a3m and written to file /home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env.a3m

# %%
insepct_msa(out_file)
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
insepct_msa("/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/startcov_60-METTL14__mmseqs2_uniref_env.a3m")
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
efa = "/home/adaddi/scratch/muscle_resampling/Sampling_stratified_CRBN__mmseqs2_uniref_env/muscleMSA__TRH-stratified_startcov_40-CRBN__mmseqs2_uniref_env/Aln-stratified_startcov_40-CRBN__mmseqs2_uniref_env.efa"
in_ = unblock_efa(efa)
out_re =  f'{in_.split(".")[0]}.@.afa'
MUSCLE = "/home/adaddi/data/muscle5/src/Linux/muscle"
command = [MUSCLE, "-resample", in_ , "-output", out_re, "-replicates", "5", "-minconf",  "0.5", "-max_gap_fract", "0.5"]
result = subprocess.run(command, capture_output=True, text=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 efa = "/home/adaddi/scratch/muscle_resampling/Sampling_stratified_CRBN__mmseqs2_uniref_env/muscleMSA__TRH-stratified_startcov_40-CRBN__mmseqs2_uniref_env/Aln-stratified_startcov_40-CRBN__mmseqs2_uniref_env.efa"
# ----> 2 in_ = unblock_efa(efa)
#       3 out_re =  f'{in_.split(".")[0]}.@.afa'
#       4 MUSCLE = "/home/adaddi/data/muscle5/src/Linux/muscle"
#
# NameError: name 'unblock_efa' is not defined

# %%
from resample_custom import *
import os

# %%
foldr = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env"
input_fastas = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(foldr)) for f in fn if f[-3:] == "afa"]
input_fastas =  [filename for filename in input_fastas if "checkpoint" or "unAln" not in filename]
output_fasta = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/re_test.fasta"
sample_one_column_from_each_msa(input_fastas, output_fasta, "QUERYSEQUENCE")
# Out:
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-----N-------DYC---QHFV----DT---G-------H-RPQNFIR-DVG...-E-')
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-----NDY---C-------------Q-----HFVDT---GH--RPQ-NFIR-D...E--')
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-NDY---C-------Q----------HFVDTGH-R---P-QN--FIR-DV-GL...-E-')
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-----N-------DYC---QHFV----DT---G-------H-RPQNFIR-DVG...-E-')
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-----NDY---C-------------Q-----HFVDT---GH--RPQ-NFIR-D...E--')
# ID: QUERYSEQUENCE
# Name: QUERYSEQUENCE
# Description: QUERYSEQUENCE
# Number of features: 0
# Seq('H-NDY---C-------Q----------HFVDTGH-R---P-QN--FIR-DV-GL...-E-')
# ...

# %%
input_fastas
# Out:
# []
