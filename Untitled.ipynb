# %%
from ResamplingMSA import reorder_afa_file, msa_fasta_to_a3m, unblock_a3m, unblock_efa
from msa_utils import *
import subprocess
HHREFROMAT = "/home/adaddi/data/hh-suite/scripts/reformat.pl"
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
in_file = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env.abc.1.afa"
re_file = f'{in_file.split(".")[0]}_re.fasta'
out_file = f'{in_file.split(".")[0]}.a3m'
reorder_afa_file(in_file, re_file)
msa_fasta_to_a3m(re_file, out_file, HHREFROMAT)
unblock_a3m(out_file)
# Out:
# REORDER QUERY ON TOP
# Has Querysequence
# MSA FASTA TO A3M
# Reformatted /home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env_re.fasta with 871 sequences from fas to a3m and written to file /home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/Aln-super5_startcov_40-METTL14__mmseqs2_uniref_env.a3m

# %%
insepct_msa("/home/adaddi/scratch/muscle_resampling/CRN_METTL3_METTL14_tcf/super5_startcov_15_g_Aln_CW_super5_startcov_15_g_Aln_CW_super5_startcov_15_g_Aln_SP0R10__mmseqs2_uniref_env_unpaired_paired.a3m")
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
insepct_msa("/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/startcov_60-METTL14__mmseqs2_uniref_env.a3m")
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
efa = "/home/adaddi/scratch/muscle_resampling/Sampling_stratified_CRBN__mmseqs2_uniref_env/muscleMSA__TRH-stratified_startcov_40-CRBN__mmseqs2_uniref_env/Aln-stratified_startcov_40-CRBN__mmseqs2_uniref_env.efa"
in_ = unblock_efa(efa)
out_re =  f'{in_.split(".")[0]}.@.afa'
MUSCLE = "/home/adaddi/data/muscle5/src/Linux/muscle"
command = [MUSCLE, "-resample", in_ , "-output", out_re, "-replicates", "5", "-minconf",  "0.5", "-max_gap_fract", "0.5"]
result = subprocess.run(command, capture_output=True, text=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 efa = "/home/adaddi/scratch/muscle_resampling/Sampling_stratified_CRBN__mmseqs2_uniref_env/muscleMSA__TRH-stratified_startcov_40-CRBN__mmseqs2_uniref_env/Aln-stratified_startcov_40-CRBN__mmseqs2_uniref_env.efa"
# ----> 2 in_ = unblock_efa(efa)
#       3 out_re =  f'{in_.split(".")[0]}.@.afa'
#       4 MUSCLE = "/home/adaddi/data/muscle5/src/Linux/muscle"
#
# NameError: name 'unblock_efa' is not defined

# %%
in_file = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/re_test.fasta"
re_file = f'{in_file.split(".")[0]}_re.fasta'
out_file = f'{in_file.split(".")[0]}.a3m'
reorder_afa_file(in_file, re_file)
msa_fasta_to_a3m(re_file, out_file, HHREFROMAT)
unblock_a3m(out_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 re_file = f'{in_file.split(".")[0]}_re.fasta'
#       3 out_file = f'{in_file.split(".")[0]}.a3m'
# ----> 4 reorder_afa_file(in_file, re_file)
#       5 msa_fasta_to_a3m(re_file, out_file, HHREFROMAT)
#       6 unblock_a3m(out_file)
#
# NameError: name 'reorder_afa_file' is not defined

# %%
from resample_custom import *
import os

# %%
foldr = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env"
input_fastas = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(foldr)) for f in fn if f[-3:] == "afa"]
input_fastas =  [filename for filename in input_fastas if "checkpoint" or "unAln" not in filename]
output_fasta = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_METTL14__mmseqs2_uniref_env/muscleMSA__ESF-super5_startcov_40-METTL14__mmseqs2_uniref_env/re_test.fasta"
sample_one_column_from_each_msa(input_fastas, output_fasta, "QUERYSEQUENCE")

# %%
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
from PrepareCustomMSA import *
import os

a3m_dir1 = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env"
a3m_dir2 = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL14__mmseqs2_uniref_env_KOP/muscleMSA__GZY-super5_startcov_15-tcfMETTL14__mmseqs2_uniref_env"
a3m_dir3 = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfCRBN__mmseqs2_uniref_env_GKD/muscleMSA__DRY-super5_startcov_15-tcfCRBN__mmseqs2_uniref_env"
out_dir =  "/home/adaddi/scratch/muscle_resampling/CRN_METTL3_METTL14_tcf"
pairing_info = "/home/adaddi/scratch/muscle_resampling/tcf_m3_m14_crbn_unpaired_paired.a3m"

xmer = "Heterodimer"
files1 = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(a3m_dir1)) for f in fn if f[-3:] == "a3m" and 'mmseqs2' in os.path.join(dp, f)]
files1=  [filename for filename in files1 if "checkpoint" or "unAln" not in filename][:5]

files2 = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(a3m_dir2)) for f in fn if f[-3:] == "a3m" and 'mmseqs2' in os.path.join(dp, f)]
files2 = [filename for filename in files2 if "checkpoint" or "unAln" not in filename][:5]

files3 = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(a3m_dir3)) for f in fn if f[-3:] == "a3m" and 'mmseqs2' in os.path.join(dp, f)]
files3 = [filename for filename in files3 if "checkpoint" or "unAln" not in filename][:5]


for file1, file2, file3 in zip(files1, files2, files3):
    params = {'file': [file1 , file2, file3], #, file1], ########
    'fname': "tcf_m3_m14_crbn",
    'gap_cutoff': 0.25,
    'resample': True,
    'n_controls': 3,
    'xmer': xmer,
    'complex_ids': ['101', '102', '103'], #######
    'sample': "resample",
    'pairing': ".",
    'msa_mode': "mmseqs2_uniref_env_unpaired_paired", ####
    'save_location': out_dir,
    'gaps_position': [[],[], []]} #,[list(range(10,18)), list(range(276,287))]} # [[],[]]} ######

    params["fname"] = generate_combined_filename(params["file"], params["gaps_position"])
    print("x", params["fname"] )
    execute_sampling(params)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# x super5_startcov_15_g_super5_startcov_15_Zb_CW_super5_startcov_15_g_super5_startcov_15_TF_CW_super5_startcov_15_g_super5_startcov_15_eX__mmseqs2_uniref_env
# Error
# super5_startcov_15_g_super5_startcov_15_Zb_CW_super5_startcov_15_g_super5_startcov_15_TF_CW_super5_startcov_15_g_super5_startcov_15_eX__mmseqs2_uniref_env 100
# [3, 3, 3]
# Error
# super5_startcov_15_g_super5_startcov_15_Zb_CW_super5_startcov_15_g_super5_startcov_15_TF_CW_super5_startcov_15_g_super5_startcov_15_eX__mmseqs2_uniref_env 100
# [3, 3, 3]
# Error
# super5_startcov_15_g_super5_startcov_15_Zb_CW_super5_startcov_15_g_super5_startcov_15_TF_CW_super5_startcov_15_g_super5_startcov_15_eX__mmseqs2_uniref_env 100
# [3, 3, 3]
# ...

# %%
f = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfCRBN__mmseqs2_uniref_env_GKD"
input_fastas = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(f)) for f in fn if f[-3:] == "afa"]
output_fasta =  "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfCRBN__mmseqs2_uniref_env_GKD/test_sample.fasta"
sample_columns(input_fastas, output_fasta, option='uniform', min_confidence=0.5, query_seq_id="101")
# Out:
# REORDER QUERY ON TOP
# Has Querysequence

# %%
in_ = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfCRBN__mmseqs2_uniref_env_GKD/filterD_0.5-tcfCRBN__mmseqs2_uniref_env.a3m"
out_fa =  in_.split(".a3m")[0] + "TTTTTESS.fasta"
out_a3m =  in_.split(".fasta")[0] + ".a3m"
msa_a3m_to_fasta(in_, out_fa, HHREFROMAT)
msa_fasta_to_a3m(out, out_a3m, HHREFROMAT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       2 out_fa =  in_.split(".a3m")[0] + "TTTTTESS.fasta"
#       3 out_a3m =  in_.split(".fasta")[0] + ".a3m"
# ----> 4 msa_a3m_to_fasta(in_, out_fa, HHREFROMAT)
#       5 msa_fasta_to_a3m(out, out_a3m, HHREFROMAT)
#
# NameError: name 'msa_a3m_to_fasta' is not defined

# %%
f = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfCRBN__mmseqs2_uniref_env_GKD"
input_fastas = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(f)) for f in fn if f[-3:] == "afa"]
df = column_confidence_stats(input_fastas, query_seq_id="101", threshold=0.5)

# %%
msas = [list(SeqIO.parse(input_fasta, "fasta")) for input_fasta in input_fastas]
column_confidence = calculate_column_confidence(msas)

for col_idx, confidence in column_confidence.items():
    print(f"Column {col_idx}: Confidence = {confidence}")


    # Prepare the data for plotting
column_indices = list(column_confidence.keys())
confidence_values = list(column_confidence.values())

# Create a bar plot
plt.bar(column_indices, confidence_values)

# Add labels and title
plt.xlabel("Column Index")
plt.ylabel("Column Confidence")
plt.title("Column Confidence per Column Index")

# Display the plot
plt.show()
# Out:
# 99762792274
# Column 64: Confidence = 0.0006777363605557439
# Column 65: Confidence = 0.0006777363605557439
# Column 66: Confidence = 0.0006777363605557439
# Column 67: Confidence = 0.0006777363605557439
# Column 68: Confidence = 0.0006777363605557439
# Column 69: Confidence = 0.3297187394103694
# Column 70: Confidence = 0.8576753642832938
# Column 71: Confidence = 0.9474754320569299
# Column 72: Confidence = 0.004066418163334463
# Column 73: Confidence = 0.944425618434429
# Column 74: Confidence = 0.856997627922738
# Column 75: Confidence = 0.9535750593019315
# Column 76: Confidence = 0.9793290410030498
# Column 77: Confidence = 0.9756014910199933
# Column 78: Confidence = 0.9627245001694341
# Column 79: Confidence = 0.9634022365299898
# Column 80: Confidence = 0.003049813622500847
# Column 81: Confidence = 0.9508641138597086
# Column 82: Confidence = 0.9532361911216537
# Column 83: Confidence = 0.9566248729244324
# Column 84: Confidence = 0.9579803456455439
# ...

# %%
from resample_custom import *
from ResamplingMSA import *
from msa_utils import *
import subprocess, os
HHREFROMAT = "/home/adaddi/data/hh-suite/scripts/reformat.pl"
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
f = "/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC"
input_fastas = [os.path.join(dp, f) for dp, dn, fn in os.walk(os.path.expanduser(f)) for f in fn if f[-3:] == "afa"]
for output_fasta in input_fastas:
    out_file = output_fasta.split(".afa")[0] + ".a3m"
    re_file = output_fasta.split(".afa")[0] + "re.afa"
    reorder_afa_file(output_fasta, re_file, ">101")
    msa_fasta_to_a3m(re_file, out_file, HHREFROMAT)
    unblock_a3m(out_file)
    insepct_msa(out_file)
# Out:
# REORDER QUERY ON TOP
# Has Querysequence
# MSA FASTA TO A3M
# Reformatted /home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.none.3rerere.afa with 7581 sequences from fas to a3m and written to file /home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.none.3rere.a3m
# Unblock a3m
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
# REORDER QUERY ON TOP
# Has Querysequence
# MSA FASTA TO A3M
# ...

# %%
input_fastas
# Out:
# ['/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.none.3rere.afa',
#  '/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.none.20.afa',
#  '/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.abc.20.afa',
#  '/home/adaddi/scratch/muscle_resampling/Sampling_super5_tcfMETTL3__mmseqs2_uniref_env_UIC/muscleMSA__IVZ-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env/Aln-super5_startcov_15-tcfMETTL3__mmseqs2_uniref_env.none.1.afa',
# ...
